# %% [markdown]
# # **Introduction**

# %% [markdown]
# This notebook is to fine-tune ELECTRA and BERT on NER and RE tasks.
# If you plan to use GPU instead of TPU, it's better to have Google Colab Pro since it gives you access to V100 GPU.
#
# To activate TPU go to Runtime -> Change Runtime and choose TPU with high memory. Also, it is better to create Google Bucket at the IOWA zone to avoid additional cost.
#
#
# If you plan to use GPU, you need to install TensorFlow-GPU. You just need to upload pretrained weights locally in this notebook, create a new folder, "finetunning," and copy all datasets there.
#
# We added slidebars to each form so you can try different hyperparameters on Dev dataset. use "do_eval":True,"do_test":false for that because we can't try different hyperparameter on test dataset.
#
# For the NER task, ELECTRA implementation uses Entity Level Evaluation. You can confirm that by looking at "finetune/tagging/tagging_metrics.py at line 99
# class EntityLevelF1Scorer(F1Scorer):
#   "Computes F1 score for entity-level tasks such as NER."

# %% [markdown]
# # **Environmental Setup**

# %%
# !git clone https://github.com/salrowili/BioM-Transformers
# Out:
# Cloning into 'BioM-Transformers'...
# remote: Enumerating objects: 51, done.
# remote: Counting objects: 100% (51/51), done.
# remote: Compressing objects: 100% (47/47), done.
# remote: Total 51 (delta 6), reused 44 (delta 4), pack-reused 0
# Unpacking objects: 100% (51/51), done.

# %% [markdown]
# Establish the connection with TPU. All credits to ALBERT team for creating this code which can be found here https://github.com/google-research/albert/blob/master/albert_glue_fine_tuning_tutorial.ipynb

# %%
# %tensorflow_version 1.x
import os
import pprint
import json
import tensorflow as tf

assert "COLAB_TPU_ADDR" in os.environ, "ERROR: Not connected to a TPU runtime; please see the first cell in this notebook for instructions!"
TPU_ADDRESS = "grpc://" + os.environ["COLAB_TPU_ADDR"] 
os.environ['TPU_ADDRESS'] ="grpc://" + os.environ["COLAB_TPU_ADDR"] 
TPU_TOPOLOGY = "2x2"
print("TPU address is", TPU_ADDRESS)

from google.colab import auth
auth.authenticate_user()
with tf.Session(TPU_ADDRESS) as session:
  print('TPU devices:')
  pprint.pprint(session.list_devices())

  # Upload credentials to TPU.
  with open('/content/adc.json', 'r') as f:
    auth_info = json.load(f)
  tf.contrib.cloud.configure_gcs(session, credentials=auth_info)
    # Now credentials are set for all future sessions on this TPU.
os.environ['TPU_Name'] = TPU_ADDRESS

# %% [markdown]
# # **Pre-Processing NER and ChemProt Dataset**

# %% [markdown]
# We need to download the pre-processing script from https://microsoft.github.io/BLURB/submit.html . This is the direct link https://microsoft.github.io/BLURB/sample_code/data_generation.tar.gz . Also we need to download Punkt Sentence Tokenizer .

# %%
# !wget https://microsoft.github.io/BLURB/sample_code/data_generation.tar.gz
# !tar -xvf data_generation.tar.gz
import nltk
nltk.download('punkt')
# Out:
# --2021-06-16 17:32:41--  https://microsoft.github.io/BLURB/sample_code/data_generation.tar.gz
# Resolving microsoft.github.io (microsoft.github.io)... 185.199.108.153, 185.199.109.153, 185.199.110.153, ...
# Connecting to microsoft.github.io (microsoft.github.io)|185.199.108.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 54142 (53K) [application/gzip]
# Saving to: ‘data_generation.tar.gz’
#
# data_generation.tar 100%[===================>]  52.87K  --.-KB/s    in 0.01s
#
# 2021-06-16 17:32:41 (5.34 MB/s) - ‘data_generation.tar.gz’ saved [54142/54142]
#
# data_generation/
# data_generation/download_BLURB_data.sh
# data_generation/indexing/
# data_generation/indexing/BioASQ/
# data_generation/indexing/BioASQ/dev_id.tsv
# data_generation/indexing/BioASQ/test_id.tsv
# data_generation/indexing/BioASQ/train_id.tsv
# data_generation/indexing/DDI/
# data_generation/indexing/DDI/dev_files.tsv
# data_generation/indexing/DDI/test_files.tsv
# data_generation/indexing/DDI/train_files.tsv
# data_generation/indexing/ebmnlp/
# data_generation/indexing/ebmnlp/dev_pmid.tsv
# data_generation/indexing/ebmnlp/test_pmid.tsv
# data_generation/indexing/ebmnlp/train_pmid.tsv
# data_generation/indexing/HoC/
# data_generation/indexing/HoC/dev_pmid.tsv
# data_generation/indexing/HoC/test_pmid.tsv
# data_generation/indexing/HoC/train_pmid.tsv
# data_generation/LICENSE.md
# data_generation/preprocessor.py
# data_generation/preprocess_BLURB_data.sh
# data_generation/README.md
# data_generation/requirements.txt
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# %%shell
# pip3 install -r /content/data_generation/requirements.txt
# cd data_generation
# sh download_BLURB_data.sh
# wget https://biocreative.bioinformatics.udel.edu/media/store/files/2017/ChemProt_Corpus.zip
# mv ChemProt_Corpus.zip raw_data
# sh preprocess_BLURB_data.sh
# Out:
# Collecting nltk==3.5
#   Downloading https://files.pythonhosted.org/packages/92/75/ce35194d8e3022203cca0d2f896dbb88689f9b3fce8e9f9cff942913519d/nltk-3.5.zip (1.4MB)
#      |████████████████████████████████| 1.4MB 6.7MB/s
# Collecting lxml==4.5.2
#   Downloading https://files.pythonhosted.org/packages/de/3c/fa420469c0d4f62ae39f19ee6505f90d00ae469f6264f4f54e61ed9d9a2c/lxml-4.5.2-cp37-cp37m-manylinux1_x86_64.whl (5.5MB)
#      |████████████████████████████████| 5.5MB 18.6MB/s
# Collecting defusedxml==0.6.0
#   Downloading https://files.pythonhosted.org/packages/06/74/9b387472866358ebc08732de3da6dc48e44b0aacd2ddaa5cb85ab7e986a2/defusedxml-0.6.0-py2.py3-none-any.whl
# Collecting python-docx==0.8.10
#   Downloading https://files.pythonhosted.org/packages/e4/83/c66a1934ed5ed8ab1dbb9931f1779079f8bca0f6bbc5793c06c4b5e7d671/python-docx-0.8.10.tar.gz (5.5MB)
#      |████████████████████████████████| 5.5MB 53.8MB/s
# Collecting unrar==0.4
#   Downloading https://files.pythonhosted.org/packages/bb/0b/53130ccd483e3db8c8a460cb579bdb21b458d5494d67a261e1a5b273fbb9/unrar-0.4-py3-none-any.whl
# Collecting zipp==2.2.0
#   Downloading https://files.pythonhosted.org/packages/46/42/f2dd964b2a6b1921b08d661138148c1bcd3f038462a44019416f2342b618/zipp-2.2.0-py36-none-any.whl
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk==3.5->-r /content/data_generation/requirements.txt (line 1)) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk==3.5->-r /content/data_generation/requirements.txt (line 1)) (1.0.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from nltk==3.5->-r /content/data_generation/requirements.txt (line 1)) (2019.12.20)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from nltk==3.5->-r /content/data_generation/requirements.txt (line 1)) (4.41.1)
# Building wheels for collected packages: nltk, python-docx
#   Building wheel for nltk (setup.py) ... done
#   Created wheel for nltk: filename=nltk-3.5-cp37-none-any.whl size=1434694 sha256=75c2912ffeaeb937db2a2fe6ddaa6cb098572fa6d34c2ff302b9fc2dee0bb304
#   Stored in directory: /root/.cache/pip/wheels/ae/8c/3f/b1fe0ba04555b08b57ab52ab7f86023639a526d8bc8d384306
#   Building wheel for python-docx (setup.py) ... done
#   Created wheel for python-docx: filename=python_docx-0.8.10-cp37-none-any.whl size=184399 sha256=1891efaf79f43140e9a87f2107f1d5766fd3935f908c37a6bfa8dac1681cab38
#   Stored in directory: /root/.cache/pip/wheels/18/0b/a0/1dd62ff812c857c9e487f27d80d53d2b40531bec1acecfa47b
# Successfully built nltk python-docx
# ERROR: importlib-resources 5.1.4 has requirement zipp>=3.1.0; python_version < "3.10", but you'll have zipp 2.2.0 which is incompatible.
# Installing collected packages: nltk, lxml, defusedxml, python-docx, unrar, zipp
#   Found existing installation: nltk 3.2.5
#     Uninstalling nltk-3.2.5:
#       Successfully uninstalled nltk-3.2.5
#   Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
#   Found existing installation: defusedxml 0.7.1
#     Uninstalling defusedxml-0.7.1:
#       Successfully uninstalled defusedxml-0.7.1
#   Found existing installation: zipp 3.4.1
#     Uninstalling zipp-3.4.1:
#       Successfully uninstalled zipp-3.4.1
# Successfully installed defusedxml-0.6.0 lxml-4.5.2 nltk-3.5 python-docx-0.8.10 unrar-0.4 zipp-2.2.0
# Cloning into 'raw_data/MTL-Bioinformatics-2016'...
# remote: Enumerating objects: 426, done.
# remote: Total 426 (delta 0), reused 0 (delta 0), pack-reused 426
# Receiving objects: 100% (426/426), 26.00 MiB | 24.68 MiB/s, done.
# Resolving deltas: 100% (221/221), done.
# --2021-06-16 17:33:26--  http://www.nactem.ac.uk/GENIA/current/Shared-tasks/JNLPBA/Train/Genia4ERtraining.tar.gz
# Resolving www.nactem.ac.uk (www.nactem.ac.uk)... 130.88.113.155
# Connecting to www.nactem.ac.uk (www.nactem.ac.uk)|130.88.113.155|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2308482 (2.2M) [application/x-gzip]
# Saving to: ‘raw_data/JNLPBA/Genia4ERtraining.tar.gz’
#
# raw_data/JNLPBA/Gen 100%[===================>]   2.20M  1.26MB/s    in 1.7s
#
# 2021-06-16 17:33:29 (1.26 MB/s) - ‘raw_data/JNLPBA/Genia4ERtraining.tar.gz’ saved [2308482/2308482]
#
# --2021-06-16 17:33:29--  http://www.nactem.ac.uk/GENIA/current/Shared-tasks/JNLPBA/Evaluation/Genia4ERtest.tar.gz
# Resolving www.nactem.ac.uk (www.nactem.ac.uk)... 130.88.113.155
# Connecting to www.nactem.ac.uk (www.nactem.ac.uk)|130.88.113.155|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 862590 (842K) [application/x-gzip]
# Saving to: ‘raw_data/JNLPBA/Genia4ERtest.tar.gz’
#
# raw_data/JNLPBA/Gen 100%[===================>] 842.37K   910KB/s    in 0.9s
#
# 2021-06-16 17:33:30 (910 KB/s) - ‘raw_data/JNLPBA/Genia4ERtest.tar.gz’ saved [862590/862590]
#
# Genia4ERtask1.iob2
# Genia4ERtask2.iob2
# LICENSE
# README.txt
# evalIOB2.pl
# sampletest1.iob2
# sampletest1.raw
# sampletest2.iob2
# sampletest2.raw
# Genia4EReval1.iob2
# Genia4EReval1.raw
# Genia4EReval2.iob2
# Genia4EReval2.raw
# LICENSE
# README.txt
# Cloning into 'raw_data/EBM-NLP'...
# remote: Enumerating objects: 200, done.
# remote: Total 200 (delta 0), reused 0 (delta 0), pack-reused 200
# Receiving objects: 100% (200/200), 83.47 MiB | 37.55 MiB/s, done.
# Resolving deltas: 100% (82/82), done.
# Cloning into 'raw_data/DDI'...
# remote: Enumerating objects: 89, done.
# remote: Total 89 (delta 0), reused 0 (delta 0), pack-reused 89
# Unpacking objects: 100% (89/89), done.
# DDIextraction_2013/test_dataset/DrugBank/Procarbazine.xml
# DDIextraction_2013/train_dataset/DrugBank/Hydrochlorothiazide_ddi.xml
# DDIextraction_2013/train_dataset/MedLine/11137320.xml
# DDIextraction_2013/train_dataset/DrugBank/Cyproheptadine_ddi.xml
# DDIextraction_2013/train_dataset/MedLine/11181395.xml
# DDIextraction_2013/test_dataset/DrugBank/Perindopril.xml
# DDIextraction_2013/train_dataset/DrugBank/Budesonide_ddi.xml
# DDIextraction_2013/train_dataset/DrugBank/Cerivastatin_ddi.xml
# DDIextraction_2013/train_dataset/DrugBank/Ceftazidime_ddi.xml
# DDIextraction_2013/train_dataset/DrugBank/Deferasirox_ddi.xml
# DDIextraction_2013/train_dataset/DrugBank/Flecainide_ddi.xml
# DDIextraction_2013/train_dataset/MedLine/8521984.xml
# DDIextraction_2013/train_dataset/DrugBank/Calcitriol_ddi.xml
# DDIextraction_2013/train_dataset/DrugBank/Atropine_ddi.xml
# DDIextraction_2013/train_dataset/DrugBank/Azithromycin_ddi.xml
# DDIextraction_2013/test_dataset/DrugBank/Succimer.xml
# DDIextraction_2013/test_dataset/MedLine/21705423.xml
# DDIextraction_2013/test_dataset/DrugBank/Thymalfasin.xml
# DDIextraction_2013/test_dataset/MedLine/21715267.xml
# DDIextraction_2013/test_dataset/DrugBank/Pegvisomant.xml
# DDIextraction_2013/train_dataset/DrugBank/Lansoprazole_ddi.xml
# DDIextraction_2013/train_dataset/DrugBank/
_ddi.xml
# DDIextraction_2013/train_dataset/DrugBank/Bisoprolol_ddi.xml
# DDIextraction_2013/train_dataset/MedLine/11114408.xml
# DDIextraction_2013/test_dataset/DrugBank/Tiotropium.xml
# DDIextraction_2013/train_dataset/DrugBank/Cefditoren_ddi.xml
# DDIextraction_2013/test_dataset/MedLine/21706316.xml
# DDIextraction_2013/train_dataset/MedLine/11197767.xml
# DDIextraction_2013/test_dataset/MedLine/21763710.xml
# DDIextraction_2013/train_dataset/DrugBank/Asparaginase_ddi.xml
# DDIextraction_2013/train_dataset/MedLine/15986716.xml
# DDIextraction_2013/train_dataset/DrugBank/Conivaptan_ddi.xml
# DDIextraction_2013/test_dataset/DrugBank/Pemoline.xml
# DDIextraction_2013/train_dataset/MedLine/11211460.xml
# DDIextraction_2013/train_dataset/DrugBank/Fludarabine_ddi.xml
# DDIextraction_2013/train_dataset/DrugBank/Nitrofurantoin_ddi.xml
# DDIextraction_2013/train_dataset/DrugBank/Chlorprothixene_ddi.xml
# DDIextraction_2013/train_dataset/DrugBank/Atorvastatin_ddi.xml
# DDIextraction_2013/train_dataset/DrugBank/Nalidixic Acid_ddi.xml
# DDIextraction_2013/test_dataset/DrugBank/Sitagliptin.xml
# DDIextraction_2013/test_dataset/DrugBank/Propoxyphene.xml
# DDIextraction_2013/train_dataset/DrugBank/Sulfacetamide_ddi.xml
# DDIextraction_2013/train_dataset/DrugBank/Diphenhydramine_ddi.xml
# DDIextraction_2013/train_dataset/MedLine/15825399.xml
# DDIextraction_2013/test_dataset/DrugBank/Methimazole.xml
# DDIextraction_2013/train_dataset/DrugBank/Entacapone_ddi.xml
# DDIextraction_2013/train_dataset/DrugBank/Amprenavir_ddi.xml
# DDIextraction_2013/train_dataset/MedLine/16649322.xml
# DDIextraction_2013/train_dataset/MedLine/11199955.xml
# DDIextraction_2013/train_dataset/DrugBank/Amantadine_ddi.xml
# --2021-06-16 17:33:46--  https://tabilab.cmpe.boun.edu.tr/BIOSSES/Downloads/BIOSSES-Dataset.rar
# Resolving tabilab.cmpe.boun.edu.tr (tabilab.cmpe.boun.edu.tr)... 79.123.177.134
# Connecting to tabilab.cmpe.boun.edu.tr (tabilab.cmpe.boun.edu.tr)|79.123.177.134|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 62578 (61K) [application/rar]
# Saving to: ‘raw_data/BIOSSES-Dataset.rar’
#
# raw_data/BIOSSES-Da 100%[===================>]  61.11K   199KB/s    in 0.3s
#
# 2021-06-16 17:33:47 (199 KB/s) - ‘raw_data/BIOSSES-Dataset.rar’ saved [62578/62578]
#
#
# UNRAR 5.50 freeware      Copyright (c) 1993-2017 Alexander Roshal
#
#
# Extracting from raw_data/BIOSSES-Dataset.rar
#
# Creating    raw_data/BIOSSES-Dataset                                  OK
#   OK
#   OK
# All OK
# Cloning into 'raw_data/pubmedqa'...
# remote: Enumerating objects: 37, done.
# remote: Total 37 (delta 0), reused 0 (delta 0), pack-reused 37
# Unpacking objects: 100% (37/37), done.
# Cloning into 'raw_data/hoc'...
# remote: Enumerating objects: 3433, done.
# remote: Total 3433 (delta 0), reused 0 (delta 0), pack-reused 3433
# Receiving objects: 100% (3433/3433), 1.82 MiB | 9.24 MiB/s, done.
# Resolving deltas: 100% (256/256), done.
# --2021-06-16 17:33:48--  https://drive.google.com/u/0/uc?id=1-jDKGcXREb2X9xTFnuiJ36PvsqoyHWcw
# Resolving drive.google.com (drive.google.com)... 142.251.6.101, 142.251.6.102, 142.251.6.138, ...
# Connecting to drive.google.com (drive.google.com)|142.251.6.101|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0s-a4-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/e7al2isb407qee4ptt1klnlgt44oj7c3/1623864825000/02943319498386455524/*/1-jDKGcXREb2X9xTFnuiJ36PvsqoyHWcw [following]
# Warning: wildcards not supported in HTTP.
# --2021-06-16 17:33:50--  https://doc-0s-a4-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/e7al2isb407qee4ptt1klnlgt44oj7c3/1623864825000/02943319498386455524/*/1-jDKGcXREb2X9xTFnuiJ36PvsqoyHWcw
# Resolving doc-0s-a4-docs.googleusercontent.com (doc-0s-a4-docs.googleusercontent.com)... 74.125.201.132, 2607:f8b0:4001:c01::84
# Connecting to doc-0s-a4-docs.googleusercontent.com (doc-0s-a4-docs.googleusercontent.com)|74.125.201.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/x-zip-compressed]
# Saving to: ‘raw_data/REdata.zip’
#
# raw_data/REdata.zip     [ <=>                ]   2.48M  --.-KB/s    in 0.01s
#
# 2021-06-16 17:33:51 (185 MB/s) - ‘raw_data/REdata.zip’ saved [2597806]
#
# Archive:  raw_data/REdata.zip
#    creating: raw_data/euadr/
#    creating: raw_data/euadr/1/
#    creating: raw_data/euadr/10/
#  extracting: raw_data/euadr/10/dev.tsv
#   inflating: raw_data/euadr/10/test.tsv
#   inflating: raw_data/euadr/10/train.tsv
#  extracting: raw_data/euadr/1/dev.tsv
#   inflating: raw_data/euadr/1/test.tsv
#   inflating: raw_data/euadr/1/train.tsv
#    creating: raw_data/euadr/2/
#  extracting: raw_data/euadr/2/dev.tsv
#   inflating: raw_data/euadr/2/test.tsv
#   inflating: raw_data/euadr/2/train.tsv
#    creating: raw_data/euadr/3/
#  extracting: raw_data/euadr/3/dev.tsv
#   inflating: raw_data/euadr/3/test.tsv
#   inflating: raw_data/euadr/3/train.tsv
#    creating: raw_data/euadr/4/
#  extracting: raw_data/euadr/4/dev.tsv
#   inflating: raw_data/euadr/4/test.tsv
#   inflating: raw_data/euadr/4/train.tsv
#    creating: raw_data/euadr/5/
#  extracting: raw_data/euadr/5/dev.tsv
#   inflating: raw_data/euadr/5/test.tsv
#   inflating: raw_data/euadr/5/train.tsv
#    creating: raw_data/euadr/6/
#  extracting: raw_data/euadr/6/dev.tsv
#   inflating: raw_data/euadr/6/test.tsv
#   inflating: raw_data/euadr/6/train.tsv
#    creating: raw_data/euadr/7/
#  extracting: raw_data/euadr/7/dev.tsv
#   inflating: raw_data/euadr/7/test.tsv
#   inflating: raw_data/euadr/7/train.tsv
#    creating: raw_data/euadr/8/
#  extracting: raw_data/euadr/8/dev.tsv
#   inflating: raw_data/euadr/8/test.tsv
#   inflating: raw_data/euadr/8/train.tsv
#    creating: raw_data/euadr/9/
#  extracting: raw_data/euadr/9/dev.tsv
#   inflating: raw_data/euadr/9/test.tsv
#   inflating: raw_data/euadr/9/train.tsv
#    creating: raw_data/GAD/
#    creating: raw_data/GAD/1/
#    creating: raw_data/GAD/10/
#  extracting: raw_data/GAD/10/dev.tsv
#   inflating: raw_data/GAD/10/test.tsv
#   inflating: raw_data/GAD/10/train.tsv
#  extracting: raw_data/GAD/1/dev.tsv
#   inflating: raw_data/GAD/1/test.tsv
#   inflating: raw_data/GAD/1/train.tsv
#    creating: raw_data/GAD/2/
#  extracting: raw_data/GAD/2/dev.tsv
#   inflating: raw_data/GAD/2/test.tsv
#   inflating: raw_data/GAD/2/train.tsv
#    creating: raw_data/GAD/3/
#  extracting: raw_data/GAD/3/dev.tsv
#   inflating: raw_data/GAD/3/test.tsv
#   inflating: raw_data/GAD/3/train.tsv
#    creating: raw_data/GAD/4/
#  extracting: raw_data/GAD/4/dev.tsv
#   inflating: raw_data/GAD/4/test.tsv
#   inflating: raw_data/GAD/4/train.tsv
#    creating: raw_data/GAD/5/
#  extracting: raw_data/GAD/5/dev.tsv
#   inflating: raw_data/GAD/5/test.tsv
#   inflating: raw_data/GAD/5/train.tsv
#    creating: raw_data/GAD/6/
#  extracting: raw_data/GAD/6/dev.tsv
#   inflating: raw_data/GAD/6/test.tsv
#   inflating: raw_data/GAD/6/train.tsv
#    creating: raw_data/GAD/7/
#  extracting: raw_data/GAD/7/dev.tsv
#   inflating: raw_data/GAD/7/test.tsv
#   inflating: raw_data/GAD/7/train.tsv
#    creating: raw_data/GAD/8/
#  extracting: raw_data/GAD/8/dev.tsv
#   inflating: raw_data/GAD/8/test.tsv
#   inflating: raw_data/GAD/8/train.tsv
#    creating: raw_data/GAD/9/
#  extracting: raw_data/GAD/9/dev.tsv
#   inflating: raw_data/GAD/9/test.tsv
#   inflating: raw_data/GAD/9/train.tsv
# --2021-06-16 17:33:51--  https://biocreative.bioinformatics.udel.edu/media/store/files/2017/ChemProt_Corpus.zip
# Resolving biocreative.bioinformatics.udel.edu (biocreative.bioinformatics.udel.edu)... 128.175.240.211
# Connecting to biocreative.bioinformatics.udel.edu (biocreative.bioinformatics.udel.edu)|128.175.240.211|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4977337 (4.7M) [application/zip]
# Saving to: ‘ChemProt_Corpus.zip’
#
# ChemProt_Corpus.zip 100%[===================>]   4.75M  18.9MB/s    in 0.3s
#
# 2021-06-16 17:33:52 (18.9 MB/s) - ‘ChemProt_Corpus.zip’ saved [4977337/4977337]
#
# Archive:  raw_data/ChemProt_Corpus.zip
#    creating: raw_data/ChemProt_Corpus/
#   inflating: raw_data/ChemProt_Corpus/chemprot_development.zip
#   inflating: raw_data/ChemProt_Corpus/chemprot_sample.zip
#   inflating: raw_data/ChemProt_Corpus/chemprot_test_gs.zip
#   inflating: raw_data/ChemProt_Corpus/chemprot_training.zip
# Archive:  raw_data/ChemProt_Corpus/chemprot_training.zip
#    creating: raw_data/ChemProt_Corpus/chemprot_training/chemprot_training/
#   inflating: raw_data/ChemProt_Corpus/chemprot_training/chemprot_training/.DS_Store
#    creating: raw_data/ChemProt_Corpus/chemprot_training/__MACOSX/
#    creating: raw_data/ChemProt_Corpus/chemprot_training/__MACOSX/chemprot_training/
#   inflating: raw_data/ChemProt_Corpus/chemprot_training/__MACOSX/chemprot_training/._.DS_Store
#   inflating: raw_data/ChemProt_Corpus/chemprot_training/chemprot_training/chemprot_training_abstracts.tsv
#   inflating: raw_data/ChemProt_Corpus/chemprot_training/chemprot_training/chemprot_training_entities.tsv
#   inflating: raw_data/ChemProt_Corpus/chemprot_training/chemprot_training/chemprot_training_gold_standard.tsv
#   inflating: raw_data/ChemProt_Corpus/chemprot_training/chemprot_training/chemprot_training_relations.tsv
#   inflating: raw_data/ChemProt_Corpus/chemprot_training/chemprot_training/Readme.pdf
# Archive:  raw_data/ChemProt_Corpus/chemprot_development.zip
#    creating: raw_data/ChemProt_Corpus/chemprot_development/chemprot_development/
#   inflating: raw_data/ChemProt_Corpus/chemprot_development/chemprot_development/.DS_Store
#    creating: raw_data/ChemProt_Corpus/chemprot_development/__MACOSX/
#    creating: raw_data/ChemProt_Corpus/chemprot_development/__MACOSX/chemprot_development/
#   inflating: raw_data/ChemProt_Corpus/chemprot_development/__MACOSX/chemprot_development/._.DS_Store
#   inflating: raw_data/ChemProt_Corpus/chemprot_development/chemprot_development/chemprot_development_abstracts.tsv
#   inflating: raw_data/ChemProt_Corpus/chemprot_development/chemprot_development/chemprot_development_entities.tsv
#   inflating: raw_data/ChemProt_Corpus/chemprot_development/chemprot_development/chemprot_development_gold_standard.tsv
#   inflating: raw_data/ChemProt_Corpus/chemprot_development/chemprot_development/chemprot_development_relations.tsv
#   inflating: raw_data/ChemProt_Corpus/chemprot_development/chemprot_development/Readme.pdf
# Archive:  raw_data/ChemProt_Corpus/chemprot_test_gs.zip
#    creating: raw_data/ChemProt_Corpus/chemprot_test_gs/chemprot_test_gs/
#   inflating: raw_data/ChemProt_Corpus/chemprot_test_gs/chemprot_test_gs/.DS_Store
#    creating: raw_data/ChemProt_Corpus/chemprot_test_gs/__MACOSX/
#    creating: raw_data/ChemProt_Corpus/chemprot_test_gs/__MACOSX/chemprot_test_gs/
#   inflating: raw_data/ChemProt_Corpus/chemprot_test_gs/__MACOSX/chemprot_test_gs/._.DS_Store
#   inflating: raw_data/ChemProt_Corpus/chemprot_test_gs/chemprot_test_gs/chemprot_test_abstracts_gs.tsv
#   inflating: raw_data/ChemProt_Corpus/chemprot_test_gs/chemprot_test_gs/chemprot_test_entities_gs.tsv
#   inflating: raw_data/ChemProt_Corpus/chemprot_test_gs/chemprot_test_gs/chemprot_test_gold_standard.tsv
#   inflating: raw_data/ChemProt_Corpus/chemprot_test_gs/chemprot_test_gs/chemprot_test_relations_gs.tsv
#   inflating: raw_data/ChemProt_Corpus/chemprot_test_gs/chemprot_test_gs/readme_test_gs.pdf
# Processing BIOSSES corpus...
# Processing DDI corpus...
# train:624
# preprocessor.py:237: DeprecationWarning: This method will be removed in future versions.  Use 'list(elem)' or iteration over elem instead.
#   for sent in root.getchildren():
# dev:90
# test:191
# Processing NER data...
# Processing PICO data...
# Reading files for starting_spans participants
# Reading files for starting_spans interventions
# Reading files for starting_spans outcomes
# Collecting anns from starting_spans participants
# 	4792 ids for train
# 	189 ids for test
# Collecting anns from starting_spans interventions
# 	4782 ids for train
# 	188 ids for test
# Collecting anns from starting_spans outcomes
# 	4670 ids for train
# 	190 ids for test
# Found 4794 ids for train
# Found 191 ids for test
# Processing HoC data...
# Processing GAD data...
# Processing chemprot corpus...

# %% [markdown]
# NER label should be in format of B-xx or I-xx so we need to fix this issue.

# %%
# !sed -i "s/\tB/\tB-disease/g" /content/data_generation/data/NCBI-disease/*.tsv
# !sed -i "s/\tI/\tI-disease/g" /content/data_generation/data/NCBI-disease/*.tsv
# !sed -i "s/\tB/\tB-chem/g" /content/data_generation/data/BC5CDR-chem/*.tsv
# !sed -i "s/\tI/\tI-chem/g" /content/data_generation/data/BC5CDR-chem/*.tsv
# !sed -i "s/\tB/\tB-disease/g" /content/data_generation/data/BC5CDR-disease/*.tsv
# !sed -i "s/\tI/\tI-disease/g" /content/data_generation/data/BC5CDR-disease/*.tsv

# %% [markdown]
# Here we need to login to our google account that has the google bucket.

# %%
# !gcloud auth login

# %% [markdown]
# copy all pre-processed dataset to our bucket . Please note that ELECTRA code will look for finetuning_data folder to locate the dataset for each task.

# %%
# !gsutil -m cp -r /content/data_generation/data/* gs://biom-transformers/ELECTRA/finetuning_data/

# %% [markdown]
# Copy the tensorflow checkpoint with the vocab.txt file. You will find the checkpoint files at our github page. For example for BioM-ELECTRA-Large model this is the link https://drive.google.com/file/d/1-60kzBf7X8Y5XiZPdNIQHql82zpOYEnE/view

# %%
# !gsutil cp -r /content/BioM-ELECTRA-Large-TF gs://biom-transformers/ELECTRA/models/

# %% [markdown]
# # **Fine-Tunning**

# %% [markdown]
# If you want to search for the best hyperparameters:
#
# *   Check both train and dev and uncheck the test option.
# *   Find the best hyperparameters using the dev dataset.
# *   Use those hyperparameters to evaluate the model on the test dataset by checking both train and test checkboxes.
#
# We use default hyperparameters in our paper to help you replicate the results.

# %%
train = True #@param {type:"boolean"}
dev = False #@param {type:"boolean"}
test = True #@param {type:"boolean"}
model= "electra" #@param ["electra", "bert"]
scale= "large" #@param ["base", "large"]
task= "NCBI-disease" #@param ["BC5CDR-disease", "BC5CDR-chem", "NCBI-disease","chemprot","bioasq7b-squadv2"]
model_path = 'gs://biom-transformers/ELECTRA/models/BioM-ELECTRA-Large-TF/model.ckpt-434200' #@param {type:"string"}
vocab_path = 'gs://biom-transformers/ELECTRA/models/BioM-ELECTRA-Large-TF/vocab.txt' #@param {type:"string"}
max_seq_length= "256" #@param ["128", "256", "384","512"]
trials= "5" #@param ["1", "2", "3","4","5","10"]
batch_size = 32 #@param {type:"slider", min:8, max:128, step:8}
learning_rate = 0.00007 #@param {type:"slider", min:0.00001, max:0.0009, step:0.00001}
epochs_num = 5 #@param {type:"slider", min:1, max:50, step:1}
os.environ['max_seq_length'] = str(max_seq_length)
os.environ['batch_size'] = str(batch_size)
os.environ['learning_rate'] = str(learning_rate)
os.environ['epochs_num'] = str(epochs_num)
os.environ['task'] = str(task)
os.environ['model_path'] = str(model_path)
os.environ['vocab_path'] = str(vocab_path)
os.environ['scale'] = str(scale)
os.environ['trials'] = str(trials)
os.environ['train'] = str.lower(str(train))
os.environ['dev'] = str.lower(str(dev))
os.environ['test'] = str.lower(str(test))
os.environ['model_name'] = str(model+"-"+scale+"-"+task+"-"+max_seq_length)
# !python3 BioM-Transformers/electra/run_finetuning.py --data-dir gs://biom-transformers/ELECTRA/ \
--model-name $model_name --hparams '{"num_trials":'"$trials"',"model_size":"'$scale'", "task_names": ["'$task'"],"do_train":'"$train"',"do_eval":'"$dev"',"do_test":'"$test"' ,"init_checkpoint":"'$model_path'","vocab_file":"'$vocab_path'","vocab_size":28895,"max_seq_length":'"$max_seq_length"',"learning_rate":'"$learning_rate"',"train_batch_size":'"$batch_size"',"num_train_epochs":'"$epochs_num"',"use_tpu":true,"tpu_name":"'$TPU_ADDRESS'","num_tpu_cores":8}'
# Out:
# ================================================================================
# Config: model=electra-large-NCBI-disease-256, trial 1/5
# ================================================================================
# answerable_classifier True
# answerable_uses_start_logits True
# answerable_weight 0.5
# beam_size 20
# data_dir gs://biom-transformers/ELECTRA/
# debug False
# do_eval False
# do_lower_case True
# do_test True
# do_train True
# doc_stride 128
# double_unordered True
# embedding_size None
# eval_batch_size 32
# evaluate_bioasq False
# gcp_project None
# init_checkpoint gs://biom-transformers/ELECTRA/models/BioM-ELECTRA-Large-TF/model.ckpt-434200
# iterations_per_loop 1000
# joint_prediction True
# keep_all_models True
# layerwise_lr_decay 0.9
# learning_rate 7e-05
# log_examples False
# max_answer_length 30
# max_query_length 64
# max_seq_length 256
# model_dir gs://biom-transformers/ELECTRA/models/electra-large-NCBI-disease-256/finetuning_models/NCBI-disease_model
# model_hparam_overrides {}
# model_name electra-large-NCBI-disease-256
# model_size large
# n_best_size 20
# n_writes_test 5
# num_tpu_cores 8
# num_train_epochs 5
# num_trials 5
# predict_batch_size 32
# preprocessed_data_dir gs://biom-transformers/ELECTRA/models/electra-large-NCBI-disease-256/finetuning_tfrecords/NCBI-disease_tfrecords
# qa_eval_file <built-in method format of str object at 0x7f88cc82c0d0>
# qa_na_file <built-in method format of str object at 0x7f88cc82c210>
# qa_na_threshold -2.75
# qa_nbest_file <built-in method format of str object at 0x7f88cc82c2b0>
# qa_preds_file <built-in method format of str object at 0x7f88cc82c170>
# raw_data_dir <built-in method format of str object at 0x7f88cc823110>
# results_pkl gs://biom-transformers/ELECTRA/models/electra-large-NCBI-disease-256/results/NCBI-disease_results.pkl
# results_txt gs://biom-transformers/ELECTRA/models/electra-large-NCBI-disease-256/results/NCBI-disease_results.txt
# save_checkpoints_steps 1000000
# task_names ['NCBI-disease']
# test_predictions <built-in method format of str object at 0x7f88cc82b3a0>
# tpu_job_name None
# tpu_name grpc://10.51.223.194:8470
# tpu_zone None
# train_batch_size 32
# use_tfrecords_if_existing True
# use_tpu True
# vocab_file gs://biom-transformers/ELECTRA/models/BioM-ELECTRA-Large-TF/vocab.txt
# vocab_size 28895
# warmup_proportion 0.1
# weight_decay_rate 0.01
# write_test_outputs False
#
# Loading dataset NCBI-disease_train
# ================================================================================
# Start training: model=electra-large-NCBI-disease-256, trial 1/5
# ================================================================================
# Training for 845 steps
# 2021-06-16 19:34:51.492838: W tensorflow/core/distributed_runtime/rpc/grpc_session.cc:370] GrpcSession::ListDevices will initialize the session with an empty graph and other defaults because the session has not yet been created.
# 2021-06-16 19:34:51.624218: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2021-06-16 19:34:51.634223: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2021-06-16 19:34:51.634267: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (1072c85ab099): /proc/driver/nvidia/version does not exist
# Building model...
# Building complete
# 2021-06-16 19:36:32.275267: W tensorflow/core/distributed_runtime/rpc/grpc_session.cc:370] GrpcSession::ListDevices will initialize the session with an empty graph and other defaults because the session has not yet been created.
#
# ================================================================================
# Run Test set evaluation: model=electra-large-NCBI-disease-256, trial 1/5
# ================================================================================
# Evaluating NCBI-disease
# Loading dataset NCBI-disease_test
# Building model...
# Building complete
# Evaluation on Named Entity
# 980
# NCBI-disease: precision: 88.16 - recall: 90.00 - f1: 89.07 - loss: 0.28
#
# Loading dataset NCBI-disease_train
# ================================================================================
# Start training: model=electra-large-NCBI-disease-256, trial 1/5
# ================================================================================
# Training for 845 steps
# 2021-06-16 19:42:38.903847: W tensorflow/core/distributed_runtime/rpc/grpc_session.cc:370] GrpcSession::ListDevices will initialize the session with an empty graph and other defaults because the session has not yet been created.
# Building model...
# Building complete
# 2021-06-16 19:44:24.288884: W tensorflow/core/distributed_runtime/rpc/grpc_session.cc:370] GrpcSession::ListDevices will initialize the session with an empty graph and other defaults because the session has not yet been created.
#
# ================================================================================
# Run Test set evaluation: model=electra-large-NCBI-disease-256, trial 1/5
# ================================================================================
# Evaluating NCBI-disease
# Loading dataset NCBI-disease_test
# Building model...
# Building complete
# Evaluation on Named Entity
# 985
# NCBI-disease: precision: 88.22 - recall: 90.52 - f1: 89.36 - loss: 0.26
#
# Loading dataset NCBI-disease_train
# ================================================================================
# Start training: model=electra-large-NCBI-disease-256, trial 1/5
# ================================================================================
# Training for 845 steps
# 2021-06-16 19:50:43.997716: W tensorflow/core/distributed_runtime/rpc/grpc_session.cc:370] GrpcSession::ListDevices will initialize the session with an empty graph and other defaults because the session has not yet been created.
# Building model...
# Building complete
# 2021-06-16 19:52:28.018976: W tensorflow/core/distributed_runtime/rpc/grpc_session.cc:370] GrpcSession::ListDevices will initialize the session with an empty graph and other defaults because the session has not yet been created.
#
# ================================================================================
# Run Test set evaluation: model=electra-large-NCBI-disease-256, trial 1/5
# ================================================================================
# Evaluating NCBI-disease
# Loading dataset NCBI-disease_test
# Building model...
# Building complete
# Evaluation on Named Entity
# 971
# NCBI-disease: precision: 88.57 - recall: 89.58 - f1: 89.07 - loss: 0.26
#
# Loading dataset NCBI-disease_train
# ================================================================================
# Start training: model=electra-large-NCBI-disease-256, trial 1/5
# ================================================================================
# Training for 845 steps
# 2021-06-16 19:59:06.659287: W tensorflow/core/distributed_runtime/rpc/grpc_session.cc:370] GrpcSession::ListDevices will initialize the session with an empty graph and other defaults because the session has not yet been created.
# Building model...
# Building complete
# 2021-06-16 20:00:50.945513: W tensorflow/core/distributed_runtime/rpc/grpc_session.cc:370] GrpcSession::ListDevices will initialize the session with an empty graph and other defaults because the session has not yet been created.
#
# ================================================================================
# Run Test set evaluation: model=electra-large-NCBI-disease-256, trial 1/5
# ================================================================================
# Evaluating NCBI-disease
# Loading dataset NCBI-disease_test
# Building model...
# Building complete
# Evaluation on Named Entity
# 986
# NCBI-disease: precision: 88.03 - recall: 90.42 - f1: 89.21 - loss: 0.28
#
# Loading dataset NCBI-disease_train
# ================================================================================
# Start training: model=electra-large-NCBI-disease-256, trial 1/5
# ================================================================================
# Training for 845 steps
# 2021-06-16 20:07:44.246472: W tensorflow/core/distributed_runtime/rpc/grpc_session.cc:370] GrpcSession::ListDevices will initialize the session with an empty graph and other defaults because the session has not yet been created.
# Building model...
# Building complete
# 2021-06-16 20:09:29.123536: W tensorflow/core/distributed_runtime/rpc/grpc_session.cc:370] GrpcSession::ListDevices will initialize the session with an empty graph and other defaults because the session has not yet been created.
#
# ================================================================================
# Run Test set evaluation: model=electra-large-NCBI-disease-256, trial 1/5
# ================================================================================
# Evaluating NCBI-disease
# Loading dataset NCBI-disease_test
# Building model...
# Building complete
# Evaluation on Named Entity
# 991
# NCBI-disease: precision: 86.88 - recall: 89.69 - f1: 88.26 - loss: 0.29

# %%
train = True #@param {type:"boolean"}
dev = False #@param {type:"boolean"}
test = True #@param {type:"boolean"}
model= "electra" #@param ["electra", "bert"]
scale= "large" #@param ["base", "large"]
task= "chemprot" #@param ["BC5CDR-disease", "BC5CDR-chem", "NCBI-disease","chemprot","bioasq7b-squadv2"]
model_path = 'gs://biom-transformers/ELECTRA/models/BioM-ELECTRA-Large-TF/model.ckpt-434200' #@param {type:"string"}
vocab_path = 'gs://biom-transformers/ELECTRA/models/BioM-ELECTRA-Large-TF/vocab.txt' #@param {type:"string"}
max_seq_length= "256" #@param ["128", "256", "384","512"]
trials= "5" #@param ["1", "2", "3","4","5","10"]
batch_size = 32 #@param {type:"slider", min:8, max:128, step:8}
learning_rate = 0.00007 #@param {type:"slider", min:0.00001, max:0.0009, step:0.00001}
epochs_num = 4 #@param {type:"slider", min:1, max:50, step:1}
os.environ['max_seq_length'] = str(max_seq_length)
os.environ['batch_size'] = str(batch_size)
os.environ['learning_rate'] = str(learning_rate)
os.environ['epochs_num'] = str(epochs_num)
os.environ['task'] = str(task)
os.environ['model_path'] = str(model_path)
os.environ['vocab_path'] = str(vocab_path)
os.environ['scale'] = str(scale)
os.environ['trials'] = str(trials)
os.environ['train'] = str.lower(str(train))
os.environ['dev'] = str.lower(str(dev))
os.environ['test'] = str.lower(str(test))
os.environ['model_name'] = str(model+"-"+scale+"-"+task+"-"+max_seq_length)
# !python3 BioM-Transformers/electra/run_finetuning.py --data-dir gs://biom-transformers/ELECTRA/ \
--model-name $model_name --hparams '{"num_trials":'"$trials"',"model_size":"'$scale'", "task_names": ["'$task'"],"do_train":'"$train"',"do_eval":'"$dev"',"do_test":'"$test"' ,"init_checkpoint":"'$model_path'","vocab_file":"'$vocab_path'","vocab_size":28895,"max_seq_length":'"$max_seq_length"',"learning_rate":'"$learning_rate"',"train_batch_size":'"$batch_size"',"num_train_epochs":'"$epochs_num"',"use_tpu":true,"tpu_name":"'$TPU_ADDRESS'","num_tpu_cores":8}'
# Out:
# ================================================================================
# Config: model=electra-large-chemprot-256, trial 1/5
# ================================================================================
# answerable_classifier True
# answerable_uses_start_logits True
# answerable_weight 0.5
# beam_size 20
# data_dir gs://biom-transformers/ELECTRA/
# debug False
# do_eval False
# do_lower_case True
# do_test True
# do_train True
# doc_stride 128
# double_unordered True
# embedding_size None
# eval_batch_size 32
# evaluate_bioasq False
# gcp_project None
# init_checkpoint gs://biom-transformers/ELECTRA/models/BioM-ELECTRA-Large-TF/model.ckpt-434200
# iterations_per_loop 1000
# joint_prediction True
# keep_all_models True
# layerwise_lr_decay 0.9
# learning_rate 7e-05
# log_examples False
# max_answer_length 30
# max_query_length 64
# max_seq_length 256
# model_dir gs://biom-transformers/ELECTRA/models/electra-large-chemprot-256/finetuning_models/chemprot_model
# model_hparam_overrides {}
# model_name electra-large-chemprot-256
# model_size large
# n_best_size 20
# n_writes_test 5
# num_tpu_cores 8
# num_train_epochs 4
# num_trials 5
# predict_batch_size 32
# preprocessed_data_dir gs://biom-transformers/ELECTRA/models/electra-large-chemprot-256/finetuning_tfrecords/chemprot_tfrecords
# qa_eval_file <built-in method format of str object at 0x7f989c55cf30>
# qa_na_file <built-in method format of str object at 0x7f98acd870d0>
# qa_na_threshold -2.75
# qa_nbest_file <built-in method format of str object at 0x7f98acd87170>
# qa_preds_file <built-in method format of str object at 0x7f98acd87030>
# raw_data_dir <built-in method format of str object at 0x7f98acd80030>
# results_pkl gs://biom-transformers/ELECTRA/models/electra-large-chemprot-256/results/chemprot_results.pkl
# results_txt gs://biom-transformers/ELECTRA/models/electra-large-chemprot-256/results/chemprot_results.txt
# save_checkpoints_steps 1000000
# task_names ['chemprot']
# test_predictions <built-in method format of str object at 0x7f98acd872b0>
# tpu_job_name None
# tpu_name grpc://10.106.94.26:8470
# tpu_zone None
# train_batch_size 32
# use_tfrecords_if_existing True
# use_tpu True
# vocab_file gs://biom-transformers/ELECTRA/models/BioM-ELECTRA-Large-TF/vocab.txt
# vocab_size 28895
# warmup_proportion 0.1
# weight_decay_rate 0.01
# write_test_outputs False
#
# Loading dataset chemprot_train
# Existing tfrecords not found so creating
# Writing example 0 of 18034
# Writing example 2000 of 18034
# Writing example 4000 of 18034
# Writing example 6000 of 18034
# Writing example 8000 of 18034
# Writing example 10000 of 18034
# Writing example 12000 of 18034
# Writing example 14000 of 18034
# Writing example 16000 of 18034
# Writing example 18000 of 18034
# ================================================================================
# Start training: model=electra-large-chemprot-256, trial 1/5
# ================================================================================
# Training for 2256 steps
# 2021-06-17 19:42:07.547982: W tensorflow/core/distributed_runtime/rpc/grpc_session.cc:370] GrpcSession::ListDevices will initialize the session with an empty graph and other defaults because the session has not yet been created.
# 2021-06-17 19:42:07.651232: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2021-06-17 19:42:07.659439: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2021-06-17 19:42:07.659477: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (3bc3cf9b7e96): /proc/driver/nvidia/version does not exist
# Building model...
# Building complete
# 2021-06-17 19:43:43.498165: W tensorflow/core/distributed_runtime/rpc/grpc_session.cc:370] GrpcSession::ListDevices will initialize the session with an empty graph and other defaults because the session has not yet been created.
# 1000/2256 = 44.3%, SPS: 3.5, ELAP: 4:48, ETA: 6:02
# 2000/2256 = 88.7%, SPS: 3.9, ELAP: 8:33, ETA: 1:06
#
# ================================================================================
# Run Test set evaluation: model=electra-large-chemprot-256, trial 1/5
# ================================================================================
# Evaluating chemprot
# Loading dataset chemprot_test
# Existing tfrecords not found so creating
# Writing example 0 of 15744
# Writing example 2000 of 15744
# Writing example 4000 of 15744
# Writing example 6000 of 15744
# Writing example 8000 of 15744
# Writing example 10000 of 15744
# Writing example 12000 of 15744
# Writing example 14000 of 15744
# Building model...
# Building complete
# chemprot: precision: 77.92 - recall: 80.49 - f1: 79.19
#
# Loading dataset chemprot_train
# ================================================================================
# Start training: model=electra-large-chemprot-256, trial 1/5
# ================================================================================
# Training for 2256 steps
# 2021-06-17 19:56:17.739456: W tensorflow/core/distributed_runtime/rpc/grpc_session.cc:370] GrpcSession::ListDevices will initialize the session with an empty graph and other defaults because the session has not yet been created.
# Building model...
# Building complete
# 2021-06-17 19:57:54.594235: W tensorflow/core/distributed_runtime/rpc/grpc_session.cc:370] GrpcSession::ListDevices will initialize the session with an empty graph and other defaults because the session has not yet been created.
# 1000/2256 = 44.3%, SPS: 3.5, ELAP: 4:49, ETA: 6:03
# 2000/2256 = 88.7%, SPS: 3.9, ELAP: 8:35, ETA: 1:06
#
# ================================================================================
# Run Test set evaluation: model=electra-large-chemprot-256, trial 1/5
# ================================================================================
# Evaluating chemprot
# Loading dataset chemprot_test
# Building model...
# Building complete
# chemprot: precision: 79.64 - recall: 79.18 - f1: 79.41
#
# Loading dataset chemprot_train
# ================================================================================
# Start training: model=electra-large-chemprot-256, trial 1/5
# ================================================================================
# Training for 2256 steps
# 2021-06-17 20:10:08.528121: W tensorflow/core/distributed_runtime/rpc/grpc_session.cc:370] GrpcSession::ListDevices will initialize the session with an empty graph and other defaults because the session has not yet been created.
# Building model...
# Building complete
# 2021-06-17 20:11:44.268770: W tensorflow/core/distributed_runtime/rpc/grpc_session.cc:370] GrpcSession::ListDevices will initialize the session with an empty graph and other defaults because the session has not yet been created.
# 1000/2256 = 44.3%, SPS: 3.5, ELAP: 4:48, ETA: 6:01
# 2000/2256 = 88.7%, SPS: 3.9, ELAP: 8:34, ETA: 1:06
#
# ================================================================================
# Run Test set evaluation: model=electra-large-chemprot-256, trial 1/5
# ================================================================================
# Evaluating chemprot
# Loading dataset chemprot_test
# Building model...
# Building complete
# chemprot: precision: 78.27 - recall: 78.68 - f1: 78.48
#
# Loading dataset chemprot_train
# ================================================================================
# Start training: model=electra-large-chemprot-256, trial 1/5
# ================================================================================
# Training for 2256 steps
# 2021-06-17 20:24:23.003780: W tensorflow/core/distributed_runtime/rpc/grpc_session.cc:370] GrpcSession::ListDevices will initialize the session with an empty graph and other defaults because the session has not yet been created.
# Building model...
# Building complete
# 2021-06-17 20:26:08.117419: W tensorflow/core/distributed_runtime/rpc/grpc_session.cc:370] GrpcSession::ListDevices will initialize the session with an empty graph and other defaults because the session has not yet been created.
# 1000/2256 = 44.3%, SPS: 3.5, ELAP: 4:49, ETA: 6:04
# 2000/2256 = 88.7%, SPS: 3.9, ELAP: 8:36, ETA: 1:06
#
# ================================================================================
# Run Test set evaluation: model=electra-large-chemprot-256, trial 1/5
# ================================================================================
# Evaluating chemprot
# Loading dataset chemprot_test
# Building model...
# Building complete
# chemprot: precision: 78.78 - recall: 80.11 - f1: 79.44
#
# Loading dataset chemprot_train
# ================================================================================
# Start training: model=electra-large-chemprot-256, trial 1/5
# ================================================================================
# Training for 2256 steps
# 2021-06-17 20:39:02.125062: W tensorflow/core/distributed_runtime/rpc/grpc_session.cc:370] GrpcSession::ListDevices will initialize the session with an empty graph and other defaults because the session has not yet been created.
# Building model...
# Building complete
# 2021-06-17 20:40:47.769669: W tensorflow/core/distributed_runtime/rpc/grpc_session.cc:370] GrpcSession::ListDevices will initialize the session with an empty graph and other defaults because the session has not yet been created.
# 1000/2256 = 44.3%, SPS: 3.5, ELAP: 4:49, ETA: 6:03
# 2000/2256 = 88.7%, SPS: 3.9, ELAP: 8:36, ETA: 1:06
#
# ================================================================================
# Run Test set evaluation: model=electra-large-chemprot-256, trial 1/5
# ================================================================================
# Evaluating chemprot
# Loading dataset chemprot_test
# Building model...
# Building complete
# chemprot: precision: 79.01 - recall: 77.05 - f1: 78.02

# %%
train = True #@param {type:"boolean"}
dev = False #@param {type:"boolean"}
test = True #@param {type:"boolean"}
model= "bert" #@param ["electra", "bert"]
scale= "large" #@param ["base", "large"]
task= "chemprot" #@param ["BC5CDR-disease", "BC5CDR-chem", "NCBI-disease","chemprot","bioasq7b-squadv2"]
model_path = 'gs://biom-transformers/ELECTRA/models/BioM-BERT-Large-TF/model.ckpt-690000' #@param {type:"string"}
vocab_path = 'gs://biom-transformers/ELECTRA/models/BioM-BERT-Large-TF/vocab.txt' #@param {type:"string"}
max_seq_length= "256" #@param ["128", "256", "384","512"]
trials= "5" #@param ["1", "2", "3","4","5","10"]
batch_size = 32 #@param {type:"slider", min:8, max:128, step:8}
learning_rate = 0.00007 #@param {type:"slider", min:0.00001, max:0.0009, step:0.00001}
epochs_num = 4 #@param {type:"slider", min:1, max:50, step:1}
os.environ['max_seq_length'] = str(max_seq_length)
os.environ['batch_size'] = str(batch_size)
os.environ['learning_rate'] = str(learning_rate)
os.environ['epochs_num'] = str(epochs_num)
os.environ['task'] = str(task)
os.environ['model_path'] = str(model_path)
os.environ['vocab_path'] = str(vocab_path)
os.environ['scale'] = str(scale)
os.environ['trials'] = str(trials)
os.environ['train'] = str.lower(str(train))
os.environ['dev'] = str.lower(str(dev))
os.environ['test'] = str.lower(str(test))
os.environ['model_name'] = str(model+"-"+scale+"-"+task+"-"+max_seq_length)
# !python3 BioM-Transformers/electra/run_finetuning.py --data-dir gs://biom-transformers/ELECTRA/ \
--model-name $model_name --hparams '{"num_trials":'"$trials"',"model_size":"'$scale'", "task_names": ["'$task'"],"do_train":'"$train"',"do_eval":'"$dev"',"do_test":'"$test"' ,"init_checkpoint":"'$model_path'","vocab_file":"'$vocab_path'","vocab_size":30000,"max_seq_length":'"$max_seq_length"',"learning_rate":'"$learning_rate"',"train_batch_size":'"$batch_size"',"num_train_epochs":'"$epochs_num"',"use_tpu":true,"tpu_name":"'$TPU_ADDRESS'","num_tpu_cores":8}'
# Out:
# ================================================================================
# Config: model=bert-large-chemprot-256, trial 1/5
# ================================================================================
# answerable_classifier True
# answerable_uses_start_logits True
# answerable_weight 0.5
# beam_size 20
# data_dir gs://biom-transformers/ELECTRA/
# debug False
# do_eval False
# do_lower_case True
# do_test True
# do_train True
# doc_stride 128
# double_unordered True
# embedding_size None
# eval_batch_size 32
# evaluate_bioasq False
# gcp_project None
# init_checkpoint gs://biom-transformers/ELECTRA/models/BioM-BERT-Large-TF/model.ckpt-690000
# iterations_per_loop 1000
# joint_prediction True
# keep_all_models True
# layerwise_lr_decay 0.9
# learning_rate 7e-05
# log_examples False
# max_answer_length 30
# max_query_length 64
# max_seq_length 256
# model_dir gs://biom-transformers/ELECTRA/models/bert-large-chemprot-256/finetuning_models/chemprot_model
# model_hparam_overrides {}
# model_name bert-large-chemprot-256
# model_size large
# n_best_size 20
# n_writes_test 5
# num_tpu_cores 8
# num_train_epochs 4
# num_trials 5
# predict_batch_size 32
# preprocessed_data_dir gs://biom-transformers/ELECTRA/models/bert-large-chemprot-256/finetuning_tfrecords/chemprot_tfrecords
# qa_eval_file <built-in method format of str object at 0x7f4dae63fe40>
# qa_na_file <built-in method format of str object at 0x7f4da5e2df30>
# qa_na_threshold -2.75
# qa_nbest_file <built-in method format of str object at 0x7f4dae643030>
# qa_preds_file <built-in method format of str object at 0x7f4da5e2de90>
# raw_data_dir <built-in method format of str object at 0x7f4dae63d490>
# results_pkl gs://biom-transformers/ELECTRA/models/bert-large-chemprot-256/results/chemprot_results.pkl
# results_txt gs://biom-transformers/ELECTRA/models/bert-large-chemprot-256/results/chemprot_results.txt
# save_checkpoints_steps 1000000
# task_names ['chemprot']
# test_predictions <built-in method format of str object at 0x7f4dae643170>
# tpu_job_name None
# tpu_name grpc://10.59.149.34:8470
# tpu_zone None
# train_batch_size 32
# use_tfrecords_if_existing True
# use_tpu True
# vocab_file gs://biom-transformers/ELECTRA/models/BioM-BERT-Large-TF/vocab.txt
# vocab_size 30000
# warmup_proportion 0.1
# weight_decay_rate 0.01
# write_test_outputs False
#
# Loading dataset chemprot_train
# ================================================================================
# Start training: model=bert-large-chemprot-256, trial 1/5
# ================================================================================
# Training for 2256 steps
# 2021-06-18 20:21:26.547553: W tensorflow/core/distributed_runtime/rpc/grpc_session.cc:370] GrpcSession::ListDevices will initialize the session with an empty graph and other defaults because the session has not yet been created.
# 2021-06-18 20:21:26.673098: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2021-06-18 20:21:26.682915: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2021-06-18 20:21:26.682960: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (30593cad1cf9): /proc/driver/nvidia/version does not exist
# Building model...
# Building complete
# 2021-06-18 20:23:07.770361: W tensorflow/core/distributed_runtime/rpc/grpc_session.cc:370] GrpcSession::ListDevices will initialize the session with an empty graph and other defaults because the session has not yet been created.
# 1000/2256 = 44.3%, SPS: 3.5, ELAP: 4:48, ETA: 6:01
# 2000/2256 = 88.7%, SPS: 3.9, ELAP: 8:35, ETA: 1:06
#
# ================================================================================
# Run Test set evaluation: model=bert-large-chemprot-256, trial 1/5
# ================================================================================
# Evaluating chemprot
# Loading dataset chemprot_test
# Building model...
# Building complete
# chemprot: precision: 80.41 - recall: 79.50 - f1: 79.95
#
# Loading dataset chemprot_train
# ================================================================================
# Start training: model=bert-large-chemprot-256, trial 1/5
# ================================================================================
# Training for 2256 steps
# 2021-06-18 20:35:23.646855: W tensorflow/core/distributed_runtime/rpc/grpc_session.cc:370] GrpcSession::ListDevices will initialize the session with an empty graph and other defaults because the session has not yet been created.
# Building model...
# Building complete
# 2021-06-18 20:37:04.563706: W tensorflow/core/distributed_runtime/rpc/grpc_session.cc:370] GrpcSession::ListDevices will initialize the session with an empty graph and other defaults because the session has not yet been created.
# 1000/2256 = 44.3%, SPS: 3.5, ELAP: 4:50, ETA: 6:04
# 2000/2256 = 88.7%, SPS: 3.9, ELAP: 8:37, ETA: 1:06
#
# ================================================================================
# Run Test set evaluation: model=bert-large-chemprot-256, trial 1/5
# ================================================================================
# Evaluating chemprot
# Loading dataset chemprot_test
# Building model...
# Building complete
# chemprot: precision: 79.16 - recall: 78.97 - f1: 79.07
#
# Loading dataset chemprot_train
# ================================================================================
# Start training: model=bert-large-chemprot-256, trial 1/5
# ================================================================================
# Training for 2256 steps
# 2021-06-18 20:48:59.238830: W tensorflow/core/distributed_runtime/rpc/grpc_session.cc:370] GrpcSession::ListDevices will initialize the session with an empty graph and other defaults because the session has not yet been created.
# Building model...
# Building complete
# 2021-06-18 20:50:41.561647: W tensorflow/core/distributed_runtime/rpc/grpc_session.cc:370] GrpcSession::ListDevices will initialize the session with an empty graph and other defaults because the session has not yet been created.
# 1000/2256 = 44.3%, SPS: 3.5, ELAP: 4:50, ETA: 6:04
# 2000/2256 = 88.7%, SPS: 3.9, ELAP: 8:36, ETA: 1:06
#
# ================================================================================
# Run Test set evaluation: model=bert-large-chemprot-256, trial 1/5
# ================================================================================
# Evaluating chemprot
# Loading dataset chemprot_test
# Building model...
# Building complete
# chemprot: precision: 80.21 - recall: 78.74 - f1: 79.47
#
# Loading dataset chemprot_train
# ================================================================================
# Start training: model=bert-large-chemprot-256, trial 1/5
# ================================================================================
# Training for 2256 steps
# 2021-06-18 21:02:45.761691: W tensorflow/core/distributed_runtime/rpc/grpc_session.cc:370] GrpcSession::ListDevices will initialize the session with an empty graph and other defaults because the session has not yet been created.
# Building model...
# Building complete
# 2021-06-18 21:04:30.986238: W tensorflow/core/distributed_runtime/rpc/grpc_session.cc:370] GrpcSession::ListDevices will initialize the session with an empty graph and other defaults because the session has not yet been created.
# 1000/2256 = 44.3%, SPS: 3.5, ELAP: 4:50, ETA: 6:04
# 2000/2256 = 88.7%, SPS: 3.9, ELAP: 8:36, ETA: 1:06
#
# ================================================================================
# Run Test set evaluation: model=bert-large-chemprot-256, trial 1/5
# ================================================================================
# Evaluating chemprot
# Loading dataset chemprot_test
# Building model...
# Building complete
# chemprot: precision: 79.04 - recall: 81.25 - f1: 80.13
#
# Loading dataset chemprot_train
# ================================================================================
# Start training: model=bert-large-chemprot-256, trial 1/5
# ================================================================================
# Training for 2256 steps
# 2021-06-18 21:16:44.364446: W tensorflow/core/distributed_runtime/rpc/grpc_session.cc:370] GrpcSession::ListDevices will initialize the session with an empty graph and other defaults because the session has not yet been created.
# Building model...
# Building complete
# 2021-06-18 21:18:27.652933: W tensorflow/core/distributed_runtime/rpc/grpc_session.cc:370] GrpcSession::ListDevices will initialize the session with an empty graph and other defaults because the session has not yet been created.
# 1000/2256 = 44.3%, SPS: 3.4, ELAP: 4:52, ETA: 6:07
# 2000/2256 = 88.7%, SPS: 3.9, ELAP: 8:38, ETA: 1:06
#
# ================================================================================
# Run Test set evaluation: model=bert-large-chemprot-256, trial 1/5
# ================================================================================
# Evaluating chemprot
# Loading dataset chemprot_test
# Building model...
# Building complete
# chemprot: precision: 80.25 - recall: 79.53 - f1: 79.89
